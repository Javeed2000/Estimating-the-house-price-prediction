# %%
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv
import pandas as pd

# %%
url=urlopen("https://www.flipkart.com/search?q=mobiles+under+15000+camera+phone&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_8_na_na_na&as-pos=1&as-type=RECENT&suggestionId=mobiles+under+15000+camera+phone%7CMobiles&requestId=ca7208a7-187c-4259-81cc-ffb186e9226e&as-searchtext=mob%20uner")

# %%
type(url)
# Out:
# http.client.HTTPResponse

# %%
url_b=url.read()

# %%
url_soup=BeautifulSoup(url_b)

# %%
url_soup
# Out:
# <!DOCTYPE html>
# ...
